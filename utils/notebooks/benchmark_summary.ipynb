# %%
import os
import math
import numpy as np
import pandas as pd
from sklearn.metrics import cohen_kappa_score
from tqdm import tqdm

# %%
_RESULT_DIR = ['../../DSClassificationResults/DSClassificationResults_keras', '../../DSClassificationResults/DSClassificationResults_sklearn', '../../DSClassificationResults/DSClassificationResults_MOA'] 
_MODEL = 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x90'
_METRICS_FILE_NAME = 'metrics.csv'
_DATA_FILE_NAME = 'data.csv'
_RES_FILE_PATH = './files/benchmark_sensitivityAnalysis2.1.csv'
#_DATASETS = sorted(os.listdir(_RESULT_DIR))

# %%
# @jit()
# def kappa_score(real, predicted):
#     classes = np.unique(np.concatenate((real,predicted)))
#     n_classes = len(classes)
#     index_classes = np.full(n_classes, np.nan)
#     for i,c in enumerate(classes):
#         index_classes[int(c)] = i
        
#     confusion_matrix = np.zeros((n_classes,n_classes))
#     for i in np.arange(len(real)):
#         confusion_matrix[int(index_classes[int(real[i])]), int(index_classes[int(predicted[i])])] += 1
        
#     sum0 = np.sum(confusion_matrix, axis=0)
#     sum1 = np.sum(confusion_matrix, axis=1)
#     expected = np.outer(sum0, sum1) / np.sum(sum0)
    
#     w_mat = np.ones((n_classes, n_classes))
#     for i in np.arange(n_classes):
#         w_mat[i,i] = 0
    
#     if np.sum(w_mat * expected) == 0:
#         return 1
#     k = np.sum(w_mat * confusion_matrix) / np.sum(w_mat * expected)
    
#     return 1 - k

def prequential_accuracy(data, fading_factor=0.98, chunk_size=10):
    # get accuracy for each instance
    accuracy = (data[data.columns[data.shape[1]-2]]==data[data.columns[data.shape[1]-1]]).astype("int")
    # every chunks should have the same size
    accuracy = accuracy.iloc[:accuracy.shape[0]-(accuracy.shape[0]%chunk_size)]
    # compute accuracy for each chunk
    accuracy = [accuracy.iloc[start:end].mean() 
                for (start,end) in [
                    (i*chunk_size, (i+1)*chunk_size) for i in range(int(accuracy.shape[0]/chunk_size))
                ]
               ]
    # compute fading factor for each chunk
    i = len(accuracy)
    fading_factor_chunks = [fading_factor**(i-k) for k in range(1, i+1)]
    fading_factor_sum = sum(fading_factor_chunks)
    # Compute the final accuracy: sum the faded accuracies 
    accuracy_faded = sum([(fading_factor_chunks[k]*accuracy[k])/fading_factor_sum for k in range(len(accuracy))])
    return accuracy_faded


def prequential_kappa(data, fading_factor=0.98, chunk_size=10):
    # every chunks should have the same size
    data_clean =  data [[data.columns[data.shape[1]-2], data.columns[data.shape[1]-1]]].astype(int)
    data_clean.columns = ["Class", "Prediction"]
    # get kappa for each chunks
    kappa = [cohen_kappa_score(data_clean.iloc[start:end]["Class"].to_numpy(), data_clean.iloc[start:end]["Prediction"].to_numpy()) 
              for (start,end) in [
                  (i*chunk_size, (i+1)*chunk_size) for i in range(int(data_clean.shape[0]/chunk_size))
              ]
             ]
    # Change NaN for 1 (kappa is nan when there is only one class in the chunk)
    kappa = [1. if math.isnan(k) else k for k in kappa]
    # compute fading factor for each chunk
    i = len(kappa)
    fading_factor_chunks = [fading_factor**(i-k) for k in range(1, i+1)]
    fading_factor_sum = sum(fading_factor_chunks)
    # compute final kappa: sum the faded kappa
    kappa_faded = sum([(fading_factor_chunks[k]*kappa[k])/fading_factor_sum for k in range(len(kappa))])
    return kappa_faded

# %%
errors = []
metrics_ls = []

for result_dir in _RESULT_DIR:
    datasets = sorted(os.listdir(result_dir))
    for dataset in tqdm(datasets, desc=result_dir):
        models = sorted(os.listdir(os.path.join(result_dir, dataset)))
        for model in models:
            # read files 
            metrics_file_path = os.path.join(result_dir, dataset, model, _METRICS_FILE_NAME)
            data_file_path = os.path.join(result_dir, dataset, model, _DATA_FILE_NAME)
            try:
                if 'MOA' in model:
                    data = pd.read_csv(data_file_path,header=None)
                else:
                    data = pd.read_csv(data_file_path,header=0)
                metrics = pd.read_csv(metrics_file_path)
                metrics.columns = [c.lower() for c in metrics.columns]
            except Exception as e:
                errors.append((model,dataset, str(e)))
                continue
            
            # compute metrics
            num_instances = data.shape[0]
            num_attributes = data.shape[1]-2
            num_classes = len(pd.unique(data[data.columns[data.shape[1]-2]].astype(int)))
            
            accuracy = prequential_accuracy(data)
            kappa = prequential_kappa(data)
            
            train_time_mean = metrics['train_time_s'].mean() if 'train_time_s' in metrics else metrics['train_time'].mean()
            test_time_mean = metrics['test_time_s'].mean() if 'test_time_s' in metrics else metrics['test_time'].mean()
            total_time_mean = (metrics['train_time_s'] + metrics['test_time_s']).mean() if 'test_time_s' in metrics else (metrics['train_time'] + metrics['test_time']).mean()
            
            train_time = metrics['train_time_s'].sum() if 'train_time_s' in metrics else metrics['train_time'].sum()
            test_time = metrics['test_time_s'].sum() if 'test_time_s' in metrics else metrics['test_time'].sum()
            total_time = (metrics['train_time_s'].sum() + metrics['test_time_s'].sum() if 'parallel' not in model else max(metrics['train_time_s'].sum(), metrics['test_time_s'].sum())) if 'test_time_s' in metrics else (metrics['train_time'].sum() + metrics['test_time'].sum() if 'parallel' not in model else max(metrics['train_time'].sum(), metrics['test_time'].sum()))
                
            metrics_summary = {'dataset':dataset,
                      'classifier':model,
                      'instances': num_instances,
                      'attributes': num_attributes,
                      'classes': num_classes,
                      'accuracy': accuracy,
                      'kappa': kappa,
                      'train_time_mean': train_time_mean,
                      'test_time_mean': test_time_mean,
                      'total_time_mean': total_time_mean,
                      'train_time': train_time,
                      'test_time': test_time,
                      'total_time': total_time        
                     }
            metrics_ls.append(metrics_summary)
        

res = pd.DataFrame(metrics_ls, columns=['dataset','classifier','instances', 'attributes', 'classes','accuracy', 'kappa', 'train_time_mean', 'test_time_mean', 'total_time_mean', 'train_time', 'test_time', 'total_time'])
res = res.sort_values(by=['dataset', 'classifier'])
res.to_csv(_RES_FILE_PATH, index=False)

if errors:
    print("Errors: " , errors)
# Out:
# ../../DSClassificationResults/DSClassificationResults_keras:   8%|▊         | 7/92 [00:07<01:37,  1.15s/it]/usr/local/share/venv/tensorflow2/lib/python3.6/site-packages/sklearn/metrics/classification.py:576: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# ../../DSClassificationResults/DSClassificationResults_keras: 100%|██████████| 92/92 [33:46<00:00, 22.03s/it]
# ../../DSClassificationResults/DSClassificationResults_sklearn: 100%|██████████| 92/92 [18:32<00:00, 12.09s/it]
# ../../DSClassificationResults/DSClassificationResults_MOA: 100%|██████████| 92/92 [1:33:13<00:00, 60.80s/it]
# Errors:  [('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40', 'BeetleFly', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40', 'BeetleFly', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40', 'BeetleFly', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40', 'BirdChicken', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40', 'BirdChicken', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40', 'BirdChicken', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120', 'Meat', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120', 'Meat', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120', 'Meat', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120', 'Meat', "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120/data.csv'"), ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x120', 'Meat', "[Errno 2 ...

# %%
result_dir = '../../DSClassificationResults/DSClassificationResults_keras'
dataset = 'Symbols'
model = 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x90'
metrics_file_path = os.path.join(result_dir, dataset, model, _METRICS_FILE_NAME)
data_file_path = os.path.join(result_dir, dataset, model, _DATA_FILE_NAME)
try:
    if 'MOA' in model:
        data = pd.read_csv(data_file_path,header=None)
    else:
        data = pd.read_csv(data_file_path,header=0)
    metrics = pd.read_csv(metrics_file_path)
    metrics.columns = [c.lower() for c in metrics.columns]
except Exception as e:
    errors.append((model,dataset, str(e)))
    print(e)

# compute metrics
num_instances = data.shape[0]
num_attributes = data.shape[1]-2
num_classes = len(pd.unique(data[data.columns[data.shape[1]-2]].astype(int)))

accuracy = prequential_accuracy(data)
kappa = prequential_kappa(data)

train_time_mean = metrics['train_time_s'].mean() if 'train_time_s' in metrics else metrics['train_time'].mean()
test_time_mean = metrics['test_time_s'].mean() if 'test_time_s' in metrics else metrics['test_time'].mean()
total_time_mean = (metrics['train_time_s'] + metrics['test_time_s']).mean() if 'test_time_s' in metrics else (metrics['train_time'] + metrics['test_time']).mean()

train_time = metrics['train_time_s'].sum() if 'train_time_s' in metrics else metrics['train_time'].sum()
test_time = metrics['test_time_s'].sum() if 'test_time_s' in metrics else metrics['test_time'].sum()
total_time = (metrics['train_time_s'].sum() + metrics['test_time_s'].sum() if 'parallel' not in model else max(metrics['train_time_s'].sum(), metrics['test_time_s'].sum())) if 'test_time_s' in metrics else (metrics['train_time'].sum() + metrics['test_time'].sum() if 'parallel' not in model else max(metrics['train_time'].sum(), metrics['test_time'].sum()))

metrics_summary = {'dataset':dataset,
          'classifier':model,
          'instances': num_instances,
          'attributes': num_attributes,
          'classes': num_classes,
          'accuracy': accuracy,
          'kappa': kappa,
          'train_time_mean': train_time_mean,
          'test_time_mean': test_time_mean,
          'total_time_mean': total_time_mean,
          'train_time': train_time,
          'test_time': test_time,
          'total_time': total_time        
         }
metrics_ls.append(metrics_summary)
print(metrics_summary)
# Out:
# {'dataset': 'Symbols', 'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x90', 'instances': 930, 'attributes': 398, 'classes': 6, 'accuracy': 0.9622742712996157, 'kappa': 0.9504801294494744, 'train_time_mean': 0.1798939271406694, 'test_time_mean': 0.1434941075064919, 'total_time_mean': 0.3233880346471613, 'train_time': 1.9788331985473633, 'test_time': 1.5784351825714111, 'total_time': 1.9788331985473633}

# %%
metrics_ls[:-1]
# Out:
# [{'dataset': 'Adiac',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 781,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.611919806950256,
#   'kappa': 0.5834770610540022,
#   'train_time_mean': 0.32695868076422274,
#   'test_time_mean': 0.0015298525492350261,
#   'total_time_mean': 0.3284885333134578,
#   'train_time': 25.502777099609375,
#   'test_time': 0.11932849884033203,
#   'total_time': 25.622105598449707},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 771,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.33278123768015766,
#   'kappa': 0.2949357540591678,
#   'train_time_mean': 0.024963057958162747,
#   'test_time_mean': 0.018223893948090382,
#   'total_time_mean': 0.04318695190625313,
#   'train_time': 1.9471185207366943,
#   'test_time': 1.4214637279510498,
#   'total_time': 1.9471185207366943},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 771,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.364045830272144,
#   'kappa': 0.32916333551107757,
#   'train_time_mean': 0.02789155642191569,
#   'test_time_mean': 0.021703869868547488,
#   'total_time_mean': 0.04959542629046318,
#   'train_time': 2.175541400909424,
#   'test_time': 1.692901849746704,
#   'total_time': 2.175541400909424},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 771,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.3183211153729974,
#   'kappa': 0.2837065875840974,
#   'train_time_mean': 0.02270827843592717,
#   'test_time_mean': 0.01607525042998485,
#   'total_time_mean': 0.03878352886591202,
#   'train_time': 1.7712457180023193,
#   'test_time': 1.2538695335388184,
#   'total_time': 1.7712457180023193},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 761,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.5016444130389258,
#   'kappa': 0.46876390504073717,
#   'train_time_mean': 0.04206498463948568,
#   'test_time_mean': 0.03177213057493552,
#   'total_time_mean': 0.0738371152144212,
#   'train_time': 1.6405344009399414,
#   'test_time': 1.2391130924224854,
#   'total_time': 1.6405344009399414},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 751,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.40803855069114464,
#   'kappa': 0.37149489305226513,
#   'train_time_mean': 0.06441968220930833,
#   'test_time_mean': 0.04881591063279372,
#   'total_time_mean': 0.11323559284210205,
#   'train_time': 1.6749117374420166,
#   'test_time': 1.2692136764526367,
#   'total_time': 1.6749117374420166},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'instances': 741,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.47559403571815734,
#   'kappa': 0.4418071853124317,
#   'train_time_mean': 0.08640354558041222,
#   'test_time_mean': 0.06709279512104235,
#   'total_time_mean': 0.15349634070145457,
#   'train_time': 1.641667366027832,
#   'test_time': 1.2747631072998047,
#   'total_time': 1.641667366027832},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 776,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.21926255684535864,
#   'kappa': 0.18693347827046164,
#   'train_time_mean': 0.013448473734733386,
#   'test_time_mean': 0.008135297359564366,
#   'total_time_mean': 0.021583771094297752,
#   'train_time': 2.097961902618408,
#   'test_time': 1.269106388092041,
#   'total_time': 2.097961902618408},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 771,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.2559923893117604,
#   'kappa': 0.22394289274074047,
#   'train_time_mean': 0.02314605468358749,
#   'test_time_mean': 0.01592875749636919,
#   'total_time_mean': 0.03907481217995668,
#   'train_time': 1.8053922653198242,
#   'test_time': 1.2424430847167969,
#   'total_time': 1.8053922653198242},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 761,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.44517877941169676,
#   'kappa': 0.410703397015386,
#   'train_time_mean': 0.04019625370319073,
#   'test_time_mean': 0.03184311206524189,
#   'total_time_mean': 0.07203936576843262,
#   'train_time': 1.5676538944244385,
#   'test_time': 1.2418813705444336,
#   'total_time': 1.5676538944244385},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 751,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.42790820601832713,
#   'kappa': 0.3930778099552598,
#   'train_time_mean': 0.06187226222111629,
#   'test_time_mean': 0.04817496813260592,
#   'total_time_mean': 0.1100472303537222,
#   'train_time': 1.6086788177490234,
#   'test_time': 1.252549171447754,
#   'total_time': 1.6086788177490234},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'instances': 741,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.45781898478527205,
#   'kappa': 0.4231954980159663,
#   'train_time_mean': 0.08233877232200221,
#   'test_time_mean': 0.06541499338651958,
#   'total_time_mean': 0.1477537657085218,
#   'train_time': 1.564436674118042,
#   'test_time': 1.242884874343872,
#   'total_time': 1.564436674118042},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 776,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.18584903349155005,
#   'kappa': 0.15315598219648882,
#   'train_time_mean': 0.013097093655512882,
#   'test_time_mean': 0.00806647233473949,
#   'total_time_mean': 0.021163565990252372,
#   'train_time': 2.0431466102600098,
#   'test_time': 1.2583696842193604,
#   'total_time': 2.0431466102600098},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 771,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.34984879882684455,
#   'kappa': 0.315271207692175,
#   'train_time_mean': 0.021721289708064154,
#   'test_time_mean': 0.016031326391758062,
#   'total_time_mean': 0.037752616099822216,
#   'train_time': 1.694260597229004,
#   'test_time': 1.250443458557129,
#   'total_time': 1.694260597229004},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 761,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.46034493407269683,
#   'kappa': 0.42565292220762696,
#   'train_time_mean': 0.04252789570735051,
#   'test_time_mean': 0.032456122911893405,
#   'total_time_mean': 0.07498401861924392,
#   'train_time': 1.65858793258667,
#   'test_time': 1.2657887935638428,
#   'total_time': 1.65858793258667},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 751,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.42228585851602063,
#   'kappa': 0.38733155558305477,
#   'train_time_mean': 0.06405658905322735,
#   'test_time_mean': 0.04886395197648268,
#   'total_time_mean': 0.11292054102971004,
#   'train_time': 1.6654713153839111,
#   'test_time': 1.2704627513885498,
#   'total_time': 1.6654713153839111},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'instances': 741,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.39117139122191624,
#   'kappa': 0.3551587488662023,
#   'train_time_mean': 0.0824534391102038,
#   'test_time_mean': 0.06642728102834601,
#   'total_time_mean': 0.1488807201385498,
#   'train_time': 1.566615343093872,
#   'test_time': 1.2621183395385742,
#   'total_time': 1.566615343093872},
#  {'dataset': 'Adiac',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 776,
#   'attributes': 176,
#   'classes': 37,
#   'accuracy': 0.22529939403409555,
#   'kappa': 0.19300286547831128,
#   'train_time_mean': 0.013088822364807129,
#   'test_time_mean': 0.00818857015707554,
#   'total_time_mean': 0.021277392521882668,
#   'train_time': 2.041856288909912,
#   'test_time': 1.2774169445037842,
#   'total_time': 2.041856288909912},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 211,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.7617778574728317,
#   'kappa': 0.627108033841542,
#   'train_time_mean': 0.18495383716764904,
#   'test_time_mean': 0.0061274596623012,
#   'total_time_mean': 0.19108129682995023,
#   'train_time': 3.88403058052063,
#   'test_time': 0.1286766529083252,
#   'total_time': 4.012707233428955},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 201,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.7740078598585513,
#   'kappa': 0.6400785605620596,
#   'train_time_mean': 0.03597147124154227,
#   'test_time_mean': 0.043953191666376026,
#   'total_time_mean': 0.07992466290791829,
#   'train_time': 0.7554008960723877,
#   'test_time': 0.9230170249938965,
#   'total_time': 0.9230170249938965},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 201,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8210592617234029,
#   'kappa': 0.7153648365323998,
#   'train_time_mean': 0.043553920019240605,
#   'test_time_mean': 0.05250058855329241,
#   'total_time_mean': 0.09605450857253302,
#   'train_time': 0.9146323204040527,
#   'test_time': 1.1025123596191406,
#   'total_time': 1.1025123596191406},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 201,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.7867882087256678,
#   'kappa': 0.6588577771354417,
#   'train_time_mean': 0.03415044148763021,
#   'test_time_mean': 0.041568937755766366,
#   'total_time_mean': 0.07571937924339658,
#   'train_time': 0.7171592712402344,
#   'test_time': 0.8729476928710938,
#   'total_time': 0.8729476928710938},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 191,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8356707560828369,
#   'kappa': 0.7364176766920718,
#   'train_time_mean': 0.06743299961090087,
#   'test_time_mean': 0.08587737083435057,
#   'total_time_mean': 0.15331037044525145,
#   'train_time': 0.6743299961090087,
#   'test_time': 0.8587737083435057,
#   'total_time': 0.8587737083435057},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 181,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8491846579993148,
#   'kappa': 0.762958370567801,
#   'train_time_mean': 0.10712310246058873,
#   'test_time_mean': 0.12528364998953684,
#   'total_time_mean': 0.23240675245012557,
#   'train_time': 0.7498617172241211,
#   'test_time': 0.8769855499267578,
#   'total_time': 0.8769855499267578},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'instances': 171,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8813086718419172,
#   'kappa': 0.8119592792410872,
#   'train_time_mean': 0.15448379516601562,
#   'test_time_mean': 0.16956720352172852,
#   'total_time_mean': 0.3240509986877441,
#   'train_time': 0.7724189758300781,
#   'test_time': 0.8478360176086426,
#   'total_time': 0.8478360176086426},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 206,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.6593261381054073,
#   'kappa': 0.4402958456474217,
#   'train_time_mean': 0.020005561056591216,
#   'test_time_mean': 0.02056883630298433,
#   'total_time_mean': 0.04057439735957554,
#   'train_time': 0.840233564376831,
#   'test_time': 0.8638911247253418,
#   'total_time': 0.8638911247253418},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 201,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.7933823809533888,
#   'kappa': 0.6658592101382109,
#   'train_time_mean': 0.03724217414855957,
#   'test_time_mean': 0.04070305824279785,
#   'total_time_mean': 0.07794523239135742,
#   'train_time': 0.782085657119751,
#   'test_time': 0.8547642230987549,
#   'total_time': 0.8547642230987549},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 191,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8484159989663786,
#   'kappa': 0.7613781277093636,
#   'train_time_mean': 0.07249019145965577,
#   'test_time_mean': 0.08429679870605469,
#   'total_time_mean': 0.15678699016571046,
#   'train_time': 0.7249019145965576,
#   'test_time': 0.8429679870605469,
#   'total_time': 0.8429679870605469},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 181,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8382853097286888,
#   'kappa': 0.7420607904637609,
#   'train_time_mean': 0.11196565628051758,
#   'test_time_mean': 0.12079317229134696,
#   'total_time_mean': 0.23275882857186453,
#   'train_time': 0.783759593963623,
#   'test_time': 0.8455522060394287,
#   'total_time': 0.8455522060394287},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'instances': 171,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8815942542866704,
#   'kappa': 0.8125931312911319,
#   'train_time_mean': 0.1587535858154297,
#   'test_time_mean': 0.16981863975524902,
#   'total_time_mean': 0.3285722255706787,
#   'train_time': 0.7937679290771484,
#   'test_time': 0.8490931987762451,
#   'total_time': 0.8490931987762451},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 206,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.5750200492673131,
#   'kappa': 0.31383176160467735,
#   'train_time_mean': 0.0178112302507673,
#   'test_time_mean': 0.020119871412004744,
#   'total_time_mean': 0.03793110166277204,
#   'train_time': 0.7480716705322266,
#   'test_time': 0.8450345993041992,
#   'total_time': 0.8450345993041992},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 201,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8116590768576347,
#   'kappa': 0.6944326923248485,
#   'train_time_mean': 0.03697818801516578,
#   'test_time_mean': 0.04109311103820801,
#   'total_time_mean': 0.07807129905337379,
#   'train_time': 0.7765419483184814,
#   'test_time': 0.8629553318023682,
#   'total_time': 0.8629553318023682},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 191,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8166940499502714,
#   'kappa': 0.7103734046464644,
#   'train_time_mean': 0.07484464645385742,
#   'test_time_mean': 0.08887784481048584,
#   'total_time_mean': 0.16372249126434327,
#   'train_time': 0.7484464645385742,
#   'test_time': 0.8887784481048584,
#   'total_time': 0.8887784481048584},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 181,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8519380324146084,
#   'kappa': 0.7643883323488515,
#   'train_time_mean': 0.09851064000810895,
#   'test_time_mean': 0.12256979942321777,
#   'total_time_mean': 0.22108043943132674,
#   'train_time': 0.6895744800567627,
#   'test_time': 0.8579885959625244,
#   'total_time': 0.8579885959625244},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'instances': 171,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.8683332658397017,
#   'kappa': 0.787860584030449,
#   'train_time_mean': 0.16430239677429198,
#   'test_time_mean': 0.17457480430603028,
#   'total_time_mean': 0.33887720108032227,
#   'train_time': 0.82151198387146,
#   'test_time': 0.8728740215301514,
#   'total_time': 0.8728740215301514},
#  {'dataset': 'ArrowHead',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 206,
#   'attributes': 251,
#   'classes': 3,
#   'accuracy': 0.5999111372646794,
#   'kappa': 0.35860021606703246,
#   'train_time_mean': 0.019684524763198125,
#   'test_time_mean': 0.02051041807447161,
#   'total_time_mean': 0.040194942837669737,
#   'train_time': 0.8267500400543213,
#   'test_time': 0.8614375591278076,
#   'total_time': 0.8614375591278076},
#  {'dataset': 'Beef',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 60,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.32931656078787824,
#   'kappa': 0.18715474524885353,
#   'train_time_mean': 0.12212514877319336,
#   'test_time_mean': 0.02075967788696289,
#   'total_time_mean': 0.14288482666015626,
#   'train_time': 0.6106257438659668,
#   'test_time': 0.10379838943481445,
#   'total_time': 0.7144241333007812},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 50,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4207588665764456,
#   'kappa': 0.2838465543814046,
#   'train_time_mean': 0.0911107063293457,
#   'test_time_mean': 0.1599578380584717,
#   'total_time_mean': 0.2510685443878174,
#   'train_time': 0.4555535316467285,
#   'test_time': 0.7997891902923584,
#   'total_time': 0.7997891902923584},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 50,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4211670298281575,
#   'kappa': 0.2671699999973019,
#   'train_time_mean': 0.08770718574523925,
#   'test_time_mean': 0.17302532196044923,
#   'total_time_mean': 0.26073250770568845,
#   'train_time': 0.43853592872619623,
#   'test_time': 0.8651266098022461,
#   'total_time': 0.8651266098022461},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 50,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4403591956516143,
#   'kappa': 0.27911472069873117,
#   'train_time_mean': 0.08625912666320801,
#   'test_time_mean': 0.15114855766296387,
#   'total_time_mean': 0.23740768432617188,
#   'train_time': 0.43129563331604004,
#   'test_time': 0.7557427883148193,
#   'total_time': 0.7557427883148193},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 40,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.6237424232119193,
#   'kappa': 0.4843900152767283,
#   'train_time_mean': 0.16611003875732422,
#   'test_time_mean': 0.36699771881103516,
#   'total_time_mean': 0.5331077575683594,
#   'train_time': 0.33222007751464844,
#   'test_time': 0.7339954376220703,
#   'total_time': 0.7339954376220703},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 30,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.5999727928173039,
#   'kappa': 0.48384430784863786,
#   'train_time_mean': 0.2851576805114746,
#   'test_time_mean': 0.7263453006744385,
#   'total_time_mean': 1.011502981185913,
#   'train_time': 0.2851576805114746,
#   'test_time': 0.7263453006744385,
#   'total_time': 0.7263453006744385},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'instances': 20,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.7989898989898989,
#   'kappa': 0.7163938312263671,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7461879253387451,
#   'total_time_mean': 0.7461879253387451,
#   'train_time': 0.0,
#   'test_time': 0.7461879253387451,
#   'total_time': 0.7461879253387451},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 55,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.31880032577122797,
#   'kappa': 0.21213976644885735,
#   'train_time_mean': 0.03518397157842463,
#   'test_time_mean': 0.06855247237465599,
#   'total_time_mean': 0.10373644395308061,
#   'train_time': 0.3870236873626709,
#   'test_time': 0.7540771961212158,
#   'total_time': 0.7540771961212158},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 50,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4615751917476352,
#   'kappa': 0.2824930767104751,
#   'train_time_mean': 0.06473174095153808,
#   'test_time_mean': 0.1521470546722412,
#   'total_time_mean': 0.2168787956237793,
#   'train_time': 0.32365870475769043,
#   'test_time': 0.760735273361206,
#   'total_time': 0.760735273361206},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 40,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.5969595980206059,
#   'kappa': 0.4675103816958558,
#   'train_time_mean': 0.1595553159713745,
#   'test_time_mean': 0.3660309314727783,
#   'total_time_mean': 0.5255862474441528,
#   'train_time': 0.319110631942749,
#   'test_time': 0.7320618629455566,
#   'total_time': 0.7320618629455566},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 30,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.6666439940144198,
#   'kappa': 0.5778548357279142,
#   'train_time_mean': 0.2798402309417725,
#   'test_time_mean': 0.7396905422210693,
#   'total_time_mean': 1.0195307731628418,
#   'train_time': 0.2798402309417725,
#   'test_time': 0.7396905422210693,
#   'total_time': 0.7396905422210693},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'instances': 20,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.797979797979798,
#   'kappa': 0.7442782252908836,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.746875524520874,
#   'total_time_mean': 0.746875524520874,
#   'train_time': 0.0,
#   'test_time': 0.746875524520874,
#   'total_time': 0.746875524520874},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 55,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4207996729098603,
#   'kappa': 0.26744240849775924,
#   'train_time_mean': 0.03340487046675249,
#   'test_time_mean': 0.07197263024070046,
#   'total_time_mean': 0.10537750070745294,
#   'train_time': 0.36745357513427734,
#   'test_time': 0.7916989326477051,
#   'total_time': 0.7916989326477051},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 50,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4611750252316831,
#   'kappa': 0.33340652881133104,
#   'train_time_mean': 0.08226180076599122,
#   'test_time_mean': 0.1569823741912842,
#   'total_time_mean': 0.2392441749572754,
#   'train_time': 0.4113090038299561,
#   'test_time': 0.7849118709564209,
#   'total_time': 0.7849118709564209},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 40,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.6232374757573697,
#   'kappa': 0.5126812239499301,
#   'train_time_mean': 0.15687596797943115,
#   'test_time_mean': 0.374503493309021,
#   'total_time_mean': 0.5313794612884521,
#   'train_time': 0.3137519359588623,
#   'test_time': 0.749006986618042,
#   'total_time': 0.749006986618042},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 30,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.6999863964086519,
#   'kappa': 0.6018709064700807,
#   'train_time_mean': 0.2963621616363525,
#   'test_time_mean': 0.7380759716033936,
#   'total_time_mean': 1.034438133239746,
#   'train_time': 0.2963621616363525,
#   'test_time': 0.7380759716033936,
#   'total_time': 0.7380759716033936},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'instances': 20,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.797979797979798,
#   'kappa': 0.7442782252908836,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7403235435485841,
#   'total_time_mean': 0.7403235435485841,
#   'train_time': 0.0,
#   'test_time': 0.7403235435485841,
#   'total_time': 0.7403235435485841},
#  {'dataset': 'Beef',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 55,
#   'attributes': 470,
#   'classes': 5,
#   'accuracy': 0.4207996729098603,
#   'kappa': 0.2550321790810493,
#   'train_time_mean': 0.03546641089699485,
#   'test_time_mean': 0.06770669330250133,
#   'total_time_mean': 0.10317310419949619,
#   'train_time': 0.39013051986694336,
#   'test_time': 0.7447736263275146,
#   'total_time': 0.7447736263275146},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 40,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7020199959192002,
#   'kappa': 0.2575656343794899,
#   'train_time_mean': 0.10638920466105144,
#   'test_time_mean': 0.033590714136759445,
#   'total_time_mean': 0.13997991879781088,
#   'train_time': 0.3191676139831543,
#   'test_time': 0.10077214241027833,
#   'total_time': 0.4199397563934326},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.5986396408651884,
#   'kappa': 0.28532708392591394,
#   'train_time_mean': 0.10112444559733073,
#   'test_time_mean': 0.2599395116170247,
#   'total_time_mean': 0.36106395721435547,
#   'train_time': 0.3033733367919922,
#   'test_time': 0.7798185348510742,
#   'total_time': 0.7798185348510742},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.4986396408651884,
#   'kappa': 0.10491326231864337,
#   'train_time_mean': 0.14657998085021973,
#   'test_time_mean': 0.2943837642669678,
#   'total_time_mean': 0.4409637451171875,
#   'train_time': 0.4397399425506592,
#   'test_time': 0.8831512928009033,
#   'total_time': 0.8831512928009033},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.566671201197116,
#   'kappa': 0.07063178964961035,
#   'train_time_mean': 0.09479061762491862,
#   'test_time_mean': 0.24088056882222494,
#   'total_time_mean': 0.33567118644714355,
#   'train_time': 0.28437185287475586,
#   'test_time': 0.7226417064666748,
#   'total_time': 0.7226417064666748},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.8494949494949495,
#   'kappa': 0.603921568627451,
#   'train_time_mean': 0.2649126052856445,
#   'test_time_mean': 0.7005257606506348,
#   'total_time_mean': 0.9654383659362793,
#   'train_time': 0.2649126052856445,
#   'test_time': 0.7005257606506348,
#   'total_time': 0.7005257606506348},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7,
#   'kappa': 0.21052631578947367,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7187173366546631,
#   'total_time_mean': 0.7187173366546631,
#   'train_time': 0.0,
#   'test_time': 0.7187173366546631,
#   'total_time': 0.7187173366546631},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6346755543463474,
#   'kappa': 0.2232053609979121,
#   'train_time_mean': 0.047146150044032505,
#   'test_time_mean': 0.10369038581848145,
#   'total_time_mean': 0.15083653586251394,
#   'train_time': 0.33002305030822754,
#   'test_time': 0.7258327007293701,
#   'total_time': 0.7258327007293701},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6673377771731737,
#   'kappa': 0.2593500824568563,
#   'train_time_mean': 0.09100770950317383,
#   'test_time_mean': 0.2391644318898519,
#   'total_time_mean': 0.3301721413930257,
#   'train_time': 0.2730231285095215,
#   'test_time': 0.7174932956695557,
#   'total_time': 0.7174932956695557},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7989898989898989,
#   'kappa': 0.5022860180754918,
#   'train_time_mean': 0.2787685394287109,
#   'test_time_mean': 0.7405524253845215,
#   'total_time_mean': 1.0193209648132324,
#   'train_time': 0.2787685394287109,
#   'test_time': 0.7405524253845215,
#   'total_time': 0.7405524253845215},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7,
#   'kappa': 0.21052631578947367,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7343530654907227,
#   'total_time_mean': 0.7343530654907227,
#   'train_time': 0.0,
#   'test_time': 0.7343530654907227,
#   'total_time': 0.7343530654907227},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.633328798802884,
#   'kappa': 0.2117974529891276,
#   'train_time_mean': 0.0453488826751709,
#   'test_time_mean': 0.10562137195042201,
#   'total_time_mean': 0.1509702546255929,
#   'train_time': 0.3174421787261963,
#   'test_time': 0.7393496036529541,
#   'total_time': 0.7393496036529541},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6339953747789416,
#   'kappa': 0.1877656115293112,
#   'train_time_mean': 0.10370016098022461,
#   'test_time_mean': 0.24773001670837402,
#   'total_time_mean': 0.35143017768859863,
#   'train_time': 0.31110048294067383,
#   'test_time': 0.7431900501251221,
#   'total_time': 0.7431900501251221},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7494949494949494,
#   'kappa': 0.4032961190855927,
#   'train_time_mean': 0.2617981433868408,
#   'test_time_mean': 0.7195916175842285,
#   'total_time_mean': 0.9813897609710693,
#   'train_time': 0.2617981433868408,
#   'test_time': 0.7195916175842285,
#   'total_time': 0.7195916175842285},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.9,
#   'kappa': 0.736842105263158,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7159547805786133,
#   'total_time_mean': 0.7159547805786133,
#   'train_time': 0.0,
#   'test_time': 0.7159547805786133,
#   'total_time': 0.7159547805786133},
#  {'dataset': 'BeetleFly',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.633328798802884,
#   'kappa': 0.2117974529891276,
#   'train_time_mean': 0.045466014317103794,
#   'test_time_mean': 0.11110687255859375,
#   'total_time_mean': 0.15657288687569754,
#   'train_time': 0.31826210021972656,
#   'test_time': 0.7777481079101562,
#   'total_time': 0.7777481079101562},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 40,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6,
#   'kappa': 0.10201999591920013,
#   'train_time_mean': 0.10614546140034993,
#   'test_time_mean': 0.0331887404123942,
#   'total_time_mean': 0.13933420181274414,
#   'train_time': 0.3184363842010498,
#   'test_time': 0.09956622123718262,
#   'total_time': 0.4180026054382324},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7,
#   'kappa': 0.3652150254623742,
#   'train_time_mean': 0.09907992680867513,
#   'test_time_mean': 0.26075315475463867,
#   'total_time_mean': 0.3598330815633138,
#   'train_time': 0.2972397804260254,
#   'test_time': 0.782259464263916,
#   'total_time': 0.782259464263916},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6653244456536527,
#   'kappa': 0.35036028194829016,
#   'train_time_mean': 0.12289206186930339,
#   'test_time_mean': 0.2804417610168457,
#   'total_time_mean': 0.4033338228861491,
#   'train_time': 0.36867618560791016,
#   'test_time': 0.8413252830505371,
#   'total_time': 0.8413252830505371},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7319820432594204,
#   'kappa': 0.3943251234776197,
#   'train_time_mean': 0.09411780039469402,
#   'test_time_mean': 0.263595978418986,
#   'total_time_mean': 0.35771377881368,
#   'train_time': 0.28235340118408203,
#   'test_time': 0.790787935256958,
#   'total_time': 0.790787935256958},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7505050505050506,
#   'kappa': 0.501010101010101,
#   'train_time_mean': 0.2826013565063477,
#   'test_time_mean': 0.7464919090270996,
#   'total_time_mean': 1.0290932655334473,
#   'train_time': 0.2826013565063477,
#   'test_time': 0.7464919090270996,
#   'total_time': 0.7464919090270996},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7,
#   'kappa': 0.44444444444444453,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7207579612731934,
#   'total_time_mean': 0.7207579612731934,
#   'train_time': 0.0,
#   'test_time': 0.7207579612731934,
#   'total_time': 0.7207579612731934},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.5660046252210583,
#   'kappa': 0.04014296137816749,
#   'train_time_mean': 0.0465573923928397,
#   'test_time_mean': 0.1034954275403704,
#   'total_time_mean': 0.1500528199332101,
#   'train_time': 0.32590174674987793,
#   'test_time': 0.7244679927825928,
#   'total_time': 0.7244679927825928},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6666575976057679,
#   'kappa': 0.26799074955788327,
#   'train_time_mean': 0.10795847574869794,
#   'test_time_mean': 0.241253932317098,
#   'total_time_mean': 0.3492124080657959,
#   'train_time': 0.3238754272460938,
#   'test_time': 0.723761796951294,
#   'total_time': 0.723761796951294},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.7505050505050506,
#   'kappa': 0.501010101010101,
#   'train_time_mean': 0.2697288990020752,
#   'test_time_mean': 0.7085278034210205,
#   'total_time_mean': 0.9782567024230957,
#   'train_time': 0.2697288990020752,
#   'test_time': 0.7085278034210205,
#   'total_time': 0.7085278034210205},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.4,
#   'kappa': 0.09090909090909083,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7637131214141846,
#   'total_time_mean': 0.7637131214141846,
#   'train_time': 0.0,
#   'test_time': 0.7637131214141846,
#   'total_time': 0.7637131214141846},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.5660046252210583,
#   'kappa': 0.04014296137816749,
#   'train_time_mean': 0.0578981808253697,
#   'test_time_mean': 0.10489538737705775,
#   'total_time_mean': 0.16279356820242746,
#   'train_time': 0.4052872657775879,
#   'test_time': 0.7342677116394043,
#   'total_time': 0.7342677116394043},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 30,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.5653244456536526,
#   'kappa': 0.1591444657518617,
#   'train_time_mean': 0.09424622853597005,
#   'test_time_mean': 0.252208948135376,
#   'total_time_mean': 0.346455176671346,
#   'train_time': 0.28273868560791016,
#   'test_time': 0.7566268444061279,
#   'total_time': 0.7566268444061279},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 20,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.8,
#   'kappa': 0.6,
#   'train_time_mean': 0.2681446075439453,
#   'test_time_mean': 0.7700953483581543,
#   'total_time_mean': 1.0382399559020996,
#   'train_time': 0.2681446075439453,
#   'test_time': 0.7700953483581543,
#   'total_time': 0.7700953483581543},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 10,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.8,
#   'kappa': 0.6,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7126972675323486,
#   'total_time_mean': 0.7126972675323486,
#   'train_time': 0.0,
#   'test_time': 0.7126972675323486,
#   'total_time': 0.7126972675323486},
#  {'dataset': 'BirdChicken',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 35,
#   'attributes': 512,
#   'classes': 2,
#   'accuracy': 0.6673513807645218,
#   'kappa': 0.23389108057860608,
#   'train_time_mean': 0.04708021027701242,
#   'test_time_mean': 0.10390731266566686,
#   'total_time_mean': 0.15098752294267928,
#   'train_time': 0.3295614719390869,
#   'test_time': 0.727351188659668,
#   'total_time': 0.727351188659668},
#  {'dataset': 'CBF',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 930,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9878592516165614,
#   'kappa': 0.9794502526954034,
#   'train_time_mean': 0.26991992670556775,
#   'test_time_mean': 0.0012569842131241508,
#   'total_time_mean': 0.2711769109186919,
#   'train_time': 24.83263325691223,
#   'test_time': 0.11564254760742188,
#   'total_time': 24.948275804519653},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 920,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9935732538550086,
#   'kappa': 0.9895012016094402,
#   'train_time_mean': 0.023642070915388023,
#   'test_time_mean': 0.01715767642726069,
#   'total_time_mean': 0.04079974734264871,
#   'train_time': 2.1750705242156982,
#   'test_time': 1.5785062313079834,
#   'total_time': 2.1750705242156982},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 920,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9939418739151251,
#   'kappa': 0.9905612040645915,
#   'train_time_mean': 0.028508168199787968,
#   'test_time_mean': 0.01971850706183392,
#   'total_time_mean': 0.04822667526162189,
#   'train_time': 2.622751474380493,
#   'test_time': 1.8141026496887207,
#   'total_time': 2.622751474380493},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 920,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.981665426349413,
#   'kappa': 0.9706894761541733,
#   'train_time_mean': 0.021143169506736424,
#   'test_time_mean': 0.01461094617843628,
#   'total_time_mean': 0.035754115685172706,
#   'train_time': 1.945171594619751,
#   'test_time': 1.3442070484161377,
#   'total_time': 1.945171594619751},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 910,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9977674531814061,
#   'kappa': 0.9965092902155022,
#   'train_time_mean': 0.03901610685431439,
#   'test_time_mean': 0.028969671415246052,
#   'total_time_mean': 0.06798577826956044,
#   'train_time': 1.794740915298462,
#   'test_time': 1.3326048851013184,
#   'total_time': 1.794740915298462},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 900,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9983336776776829,
#   'kappa': 0.9973276626792712,
#   'train_time_mean': 0.059103139241536456,
#   'test_time_mean': 0.044376095136006675,
#   'total_time_mean': 0.10347923437754313,
#   'train_time': 1.7730941772460938,
#   'test_time': 1.3312828540802002,
#   'total_time': 1.7730941772460938},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'instances': 890,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9995866325510504,
#   'kappa': 0.9993640500785391,
#   'train_time_mean': 0.07508058133332626,
#   'test_time_mean': 0.058271750159885574,
#   'total_time_mean': 0.13335233149321182,
#   'train_time': 1.726853370666504,
#   'test_time': 1.3402502536773682,
#   'total_time': 1.726853370666504},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x5',
#   'instances': 925,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9846462956425787,
#   'kappa': 0.9747909909897665,
#   'train_time_mean': 0.01308140110325169,
#   'test_time_mean': 0.007389823810474293,
#   'total_time_mean': 0.020471224913725983,
#   'train_time': 2.4200592041015625,
#   'test_time': 1.3671174049377441,
#   'total_time': 2.4200592041015625},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x10',
#   'instances': 920,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9914865708968451,
#   'kappa': 0.9872405426795208,
#   'train_time_mean': 0.02150117055229519,
#   'test_time_mean': 0.01460117360819941,
#   'total_time_mean': 0.0361023441604946,
#   'train_time': 1.9781076908111572,
#   'test_time': 1.3433079719543457,
#   'total_time': 1.9781076908111572},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x20',
#   'instances': 910,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9970562103289862,
#   'kappa': 0.9951555912131872,
#   'train_time_mean': 0.037584781646728516,
#   'test_time_mean': 0.02872634452322255,
#   'total_time_mean': 0.06631112616995107,
#   'train_time': 1.7288999557495117,
#   'test_time': 1.3214118480682373,
#   'total_time': 1.7288999557495117},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x30',
#   'instances': 900,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9940823120029989,
#   'kappa': 0.9903892729693794,
#   'train_time_mean': 0.05702805519104004,
#   'test_time_mean': 0.04651379585266113,
#   'total_time_mean': 0.10354185104370117,
#   'train_time': 1.7108416557312012,
#   'test_time': 1.395413875579834,
#   'total_time': 1.7108416557312012},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'instances': 890,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9968863950079202,
#   'kappa': 0.9947127887526782,
#   'train_time_mean': 0.08031636735667354,
#   'test_time_mean': 0.061015408972035286,
#   'total_time_mean': 0.1413317763287088,
#   'train_time': 1.8472764492034912,
#   'test_time': 1.4033544063568115,
#   'total_time': 1.8472764492034912},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x5',
#   'instances': 925,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9835016521994002,
#   'kappa': 0.9744433964818661,
#   'train_time_mean': 0.012255669928885795,
#   'test_time_mean': 0.007218132792292414,
#   'total_time_mean': 0.01947380272117821,
#   'train_time': 2.267298936843872,
#   'test_time': 1.3353545665740967,
#   'total_time': 2.267298936843872},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 920,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9859543497832536,
#   'kappa': 0.9775309266269059,
#   'train_time_mean': 0.020624533943507984,
#   'test_time_mean': 0.01450677021690037,
#   'total_time_mean': 0.03513130416040835,
#   'train_time': 1.8974571228027344,
#   'test_time': 1.334622859954834,
#   'total_time': 1.8974571228027344},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 910,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9965547832875387,
#   'kappa': 0.994703019706409,
#   'train_time_mean': 0.03780596670897111,
#   'test_time_mean': 0.029431747353595238,
#   'total_time_mean': 0.06723771406256634,
#   'train_time': 1.739074468612671,
#   'test_time': 1.3538603782653809,
#   'total_time': 1.739074468612671},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 900,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9982056129861198,
#   'kappa': 0.9964797133269915,
#   'train_time_mean': 0.05705132484436035,
#   'test_time_mean': 0.04523165225982666,
#   'total_time_mean': 0.10228297710418702,
#   'train_time': 1.7115397453308105,
#   'test_time': 1.3569495677947998,
#   'total_time': 1.7115397453308105},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'instances': 890,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.9993808230781566,
#   'kappa': 0.9990474201202407,
#   'train_time_mean': 0.07052250530408777,
#   'test_time_mean': 0.0578543932541557,
#   'total_time_mean': 0.12837689855824347,
#   'train_time': 1.6220176219940186,
#   'test_time': 1.330651044845581,
#   'total_time': 1.6220176219940186},
#  {'dataset': 'CBF',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 925,
#   'attributes': 128,
#   'classes': 3,
#   'accuracy': 0.983783804501141,
#   'kappa': 0.9738841507595926,
#   'train_time_mean': 0.012575104429915145,
#   'test_time_mean': 0.007268323125065984,
#   'total_time_mean': 0.019843427554981127,
#   'train_time': 2.3263943195343018,
#   'test_time': 1.344639778137207,
#   'total_time': 2.3263943195343018},
#  {'dataset': 'Car',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 120,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.41926352973806896,
#   'kappa': 0.2265519432444779,
#   'train_time_mean': 0.23665282943032004,
#   'test_time_mean': 0.010635549371892756,
#   'total_time_mean': 0.2472883788022128,
#   'train_time': 2.6031811237335205,
#   'test_time': 0.11699104309082031,
#   'total_time': 2.720172166824341},
#  {'dataset': 'Car',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 110,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.6056058090766896,
#   'kappa': 0.4421376709287075,
#   'train_time_mean': 0.04600420865145596,
#   'test_time_mean': 0.08192393996498802,
#   'total_time_mean': 0.12792814861644397,
#   'train_time': 0.5060462951660156,
#   'test_time': 0.9011633396148682,
#   'total_time': 0.9011633396148682},
#  {'dataset': 'Car',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 110,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.6029149190220928,
#   'kappa': 0.44392760307787094,
#   'train_time_mean': 0.059904315254905006,
#   'test_time_mean': 0.08841674978082831,
#   'total_time_mean': 0.1483210650357333,
#   'train_time': 0.6589474678039551,
#   'test_time': 0.9725842475891113,
#   'total_time': 0.9725842475891113},
#  {'dataset': 'Car',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x10',
#   'instances': 110,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.6237781513648344,
#   'kappa': 0.4731332448325992,
#   'train_time_mean': 0.04622726006941362,
#   'test_time_mean': 0.07378151200034401,
#   'total_time_mean': 0.12000877206975763,
#   'train_time': 0.5084998607635498,
#   'test_time': 0.8115966320037842,
#   'total_time': 0.8115966320037842},
#  {'dataset': 'Car',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x20',
#   'instances': 100,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.6987202825436499,
#   'kappa': 0.5728647953940006,
#   'train_time_mean': 0.10289802551269531,
#   'test_time_mean': 0.15890159606933593,
#   'total_time_mean': 0.26179962158203124,
#   'train_time': 0.5144901275634766,
#   'test_time': 0.7945079803466797,
#   'total_time': 0.7945079803466797},
#  {'dataset': 'Car',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x30',
#   'instances': 90,
#   'attributes': 577,
#   'classes': 4,
#   'accuracy': 0.6907660834759878,
#   'kappa': 0.5585366641042423,
#   'train_time_mean': 0.13899747530619302,
#   'test_time_mean': 0.26032376289367676,
# ...
#   'classes': 2,
#   'accuracy': 0.7866794001868425,
#   'kappa': 0.47306711439428684,
#   'train_time_mean': 0.023841986289391152,
#   'test_time_mean': 0.021170365504729442,
#   'total_time_mean': 0.045012351794120595,
#   'train_time': 0.9298374652862549,
#   'test_time': 0.8256442546844482,
#   'total_time': 0.9298374652862549},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x50',
#   'instances': 150,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8443649800426093,
#   'kappa': 0.6389594745259511,
#   'train_time_mean': 0.26108447710673016,
#   'test_time_mean': 0.2689064343770345,
#   'total_time_mean': 0.5299909114837646,
#   'train_time': 0.7832534313201904,
#   'test_time': 0.8067193031311035,
#   'total_time': 0.8067193031311035},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x60',
#   'instances': 140,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8834967820206892,
#   'kappa': 0.7153980835646704,
#   'train_time_mean': 0.2347106138865153,
#   'test_time_mean': 0.2658037344614665,
#   'total_time_mean': 0.5005143483479818,
#   'train_time': 0.7041318416595459,
#   'test_time': 0.7974112033843994,
#   'total_time': 0.7974112033843994},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x70',
#   'instances': 130,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8768258915028101,
#   'kappa': 0.7188076474213208,
#   'train_time_mean': 0.3137373924255371,
#   'test_time_mean': 0.39682042598724365,
#   'total_time_mean': 0.7105578184127808,
#   'train_time': 0.6274747848510742,
#   'test_time': 0.7936408519744873,
#   'total_time': 0.7936408519744873},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x80',
#   'instances': 120,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8931698857937821,
#   'kappa': 0.7495987108101029,
#   'train_time_mean': 0.31751108169555664,
#   'test_time_mean': 0.39065659046173096,
#   'total_time_mean': 0.7081676721572876,
#   'train_time': 0.6350221633911133,
#   'test_time': 0.7813131809234619,
#   'total_time': 0.7813131809234619},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x90',
#   'instances': 110,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8533404645636286,
#   'kappa': 0.6770540838898638,
#   'train_time_mean': 0.36052632331848145,
#   'test_time_mean': 0.3817100524902344,
#   'total_time_mean': 0.7422363758087158,
#   'train_time': 0.7210526466369629,
#   'test_time': 0.7634201049804688,
#   'total_time': 0.7634201049804688},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x10',
#   'instances': 190,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8364206735301952,
#   'kappa': 0.6131526266513119,
#   'train_time_mean': 0.0392576769778603,
#   'test_time_mean': 0.04282184651023463,
#   'total_time_mean': 0.08207952348809493,
#   'train_time': 0.7458958625793457,
#   'test_time': 0.813615083694458,
#   'total_time': 0.813615083694458},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x100',
#   'instances': 100,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8416321256702413,
#   'kappa': 0.6451040630070762,
#   'train_time_mean': 0.6896355152130127,
#   'test_time_mean': 0.7525956630706787,
#   'total_time_mean': 1.4422311782836914,
#   'train_time': 0.6896355152130127,
#   'test_time': 0.7525956630706787,
#   'total_time': 0.7525956630706787},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x110',
#   'instances': 90,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8979741596498555,
#   'kappa': 0.7528433794301003,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7544088363647461,
#   'total_time_mean': 0.7544088363647461,
#   'train_time': 0.0,
#   'test_time': 0.7544088363647461,
#   'total_time': 0.7544088363647461},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x120',
#   'instances': 80,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.9111446877107447,
#   'kappa': 0.7765034080195466,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7525527477264404,
#   'total_time_mean': 0.7525527477264404,
#   'train_time': 0.0,
#   'test_time': 0.7525527477264404,
#   'total_time': 0.7525527477264404},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x20',
#   'instances': 180,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8355264585872396,
#   'kappa': 0.6051401443750378,
#   'train_time_mean': 0.08284433682759602,
#   'test_time_mean': 0.09039372868008083,
#   'total_time_mean': 0.17323806550767687,
#   'train_time': 0.7455990314483643,
#   'test_time': 0.8135435581207275,
#   'total_time': 0.8135435581207275},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x30',
#   'instances': 170,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8817339385736149,
#   'kappa': 0.7205942295005188,
#   'train_time_mean': 0.12040833632151286,
#   'test_time_mean': 0.13663085301717123,
#   'total_time_mean': 0.2570391893386841,
#   'train_time': 0.7224500179290771,
#   'test_time': 0.8197851181030273,
#   'total_time': 0.8197851181030273},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'instances': 160,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8478611688451998,
#   'kappa': 0.639108991119802,
#   'train_time_mean': 0.1820918321609497,
#   'test_time_mean': 0.1984357237815857,
#   'total_time_mean': 0.3805275559425354,
#   'train_time': 0.7283673286437988,
#   'test_time': 0.7937428951263428,
#   'total_time': 0.7937428951263428},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x5',
#   'instances': 195,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8006594588314805,
#   'kappa': 0.5523061662712319,
#   'train_time_mean': 0.02193029110248272,
#   'test_time_mean': 0.020838236197447166,
#   'total_time_mean': 0.04276852729992989,
#   'train_time': 0.8552813529968262,
#   'test_time': 0.8126912117004395,
#   'total_time': 0.8552813529968262},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x50',
#   'instances': 150,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8584975817506703,
#   'kappa': 0.6859167203528298,
#   'train_time_mean': 0.2603197892506917,
#   'test_time_mean': 0.26678093274434406,
#   'total_time_mean': 0.5271007219950358,
#   'train_time': 0.7809593677520752,
#   'test_time': 0.8003427982330322,
#   'total_time': 0.8003427982330322},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x60',
#   'instances': 140,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8840572950481029,
#   'kappa': 0.7233801902361221,
#   'train_time_mean': 0.22650973002115884,
#   'test_time_mean': 0.26027480761210126,
#   'total_time_mean': 0.4867845376332601,
#   'train_time': 0.6795291900634766,
#   'test_time': 0.7808244228363037,
#   'total_time': 0.7808244228363037},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x70',
#   'instances': 130,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8786132596341231,
#   'kappa': 0.7183155339639961,
#   'train_time_mean': 0.30269432067871094,
#   'test_time_mean': 0.3993842601776123,
#   'total_time_mean': 0.7020785808563232,
#   'train_time': 0.6053886413574219,
#   'test_time': 0.7987685203552246,
#   'total_time': 0.7987685203552246},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x80',
#   'instances': 120,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8917563212193321,
#   'kappa': 0.7625786429431118,
#   'train_time_mean': 0.3216273784637451,
#   'test_time_mean': 0.38220250606536865,
#   'total_time_mean': 0.7038298845291138,
#   'train_time': 0.6432547569274902,
#   'test_time': 0.7644050121307373,
#   'total_time': 0.7644050121307373},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x90',
#   'instances': 110,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8813249021693965,
#   'kappa': 0.7156174357780141,
#   'train_time_mean': 0.3620806932449341,
#   'test_time_mean': 0.38658833503723145,
#   'total_time_mean': 0.7486690282821655,
#   'train_time': 0.7241613864898682,
#   'test_time': 0.7731766700744629,
#   'total_time': 0.7731766700744629},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x10',
#   'instances': 190,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8461873250596721,
#   'kappa': 0.6328956040735911,
#   'train_time_mean': 0.04066961689999229,
#   'test_time_mean': 0.04505134883679842,
#   'total_time_mean': 0.08572096573679071,
#   'train_time': 0.7727227210998535,
#   'test_time': 0.8559756278991699,
#   'total_time': 0.8559756278991699},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x100',
#   'instances': 100,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8418379325782216,
#   'kappa': 0.6418484134634229,
#   'train_time_mean': 0.7430815696716309,
#   'test_time_mean': 0.7616143226623535,
#   'total_time_mean': 1.5046958923339844,
#   'train_time': 0.7430815696716309,
#   'test_time': 0.7616143226623535,
#   'total_time': 0.7616143226623535},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x110',
#   'instances': 90,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.888473377130678,
#   'kappa': 0.7325763025009151,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7490708827972412,
#   'total_time_mean': 0.7490708827972412,
#   'train_time': 0.0,
#   'test_time': 0.7490708827972412,
#   'total_time': 0.7490708827972412},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x120',
#   'instances': 80,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8737784720569598,
#   'kappa': 0.704097797902928,
#   'train_time_mean': 0.0,
#   'test_time_mean': 0.7525959014892578,
#   'total_time_mean': 0.7525959014892578,
#   'train_time': 0.0,
#   'test_time': 0.7525959014892578,
#   'total_time': 0.7525959014892578},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x20',
#   'instances': 180,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8472604099081861,
#   'kappa': 0.6406574738756,
#   'train_time_mean': 0.08199779192606609,
#   'test_time_mean': 0.09023459752400716,
#   'total_time_mean': 0.17223238945007324,
#   'train_time': 0.7379801273345947,
#   'test_time': 0.8121113777160645,
#   'total_time': 0.8121113777160645},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x30',
#   'instances': 170,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8769325586761769,
#   'kappa': 0.7140986289000544,
#   'train_time_mean': 0.12069571018218994,
#   'test_time_mean': 0.13346834977467856,
#   'total_time_mean': 0.25416405995686847,
#   'train_time': 0.7241742610931396,
#   'test_time': 0.8008100986480713,
#   'total_time': 0.8008100986480713},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x40',
#   'instances': 160,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8736063273384772,
#   'kappa': 0.6961733627130003,
#   'train_time_mean': 0.18464362621307373,
#   'test_time_mean': 0.19864869117736816,
#   'total_time_mean': 0.3832923173904419,
#   'train_time': 0.7385745048522949,
#   'test_time': 0.7945947647094727,
#   'total_time': 0.7945947647094727},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x5',
#   'instances': 195,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.7487146258891859,
#   'kappa': 0.4161885080390067,
#   'train_time_mean': 0.019925765502147186,
#   'test_time_mean': 0.021462299884893954,
#   'total_time_mean': 0.041388065387041144,
#   'train_time': 0.7771048545837402,
#   'test_time': 0.8370296955108643,
#   'total_time': 0.8370296955108643},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x50',
#   'instances': 150,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8723250607142482,
#   'kappa': 0.7101664964863952,
#   'train_time_mean': 0.26864171028137207,
#   'test_time_mean': 0.2708028157552083,
#   'total_time_mean': 0.5394445260365804,
#   'train_time': 0.8059251308441162,
#   'test_time': 0.812408447265625,
#   'total_time': 0.812408447265625},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x60',
#   'instances': 140,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8791564490244925,
#   'kappa': 0.7197294061076673,
#   'train_time_mean': 0.2467618783315023,
#   'test_time_mean': 0.2643249034881592,
#   'total_time_mean': 0.5110867818196615,
#   'train_time': 0.7402856349945068,
#   'test_time': 0.7929747104644775,
#   'total_time': 0.7929747104644775},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x70',
#   'instances': 130,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.869421670425725,
#   'kappa': 0.6849438444953623,
#   'train_time_mean': 0.29986298084259033,
#   'test_time_mean': 0.3940504789352417,
#   'total_time_mean': 0.693913459777832,
#   'train_time': 0.5997259616851807,
#   'test_time': 0.7881009578704834,
#   'total_time': 0.7881009578704834},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x80',
#   'instances': 120,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8833588199133181,
#   'kappa': 0.7443232053213421,
#   'train_time_mean': 0.32076072692871094,
#   'test_time_mean': 0.3804185390472412,
#   'total_time_mean': 0.7011792659759521,
#   'train_time': 0.6415214538574219,
#   'test_time': 0.7608370780944824,
#   'total_time': 0.7608370780944824},
#  {'dataset': 'ECG200',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x90',
#   'instances': 110,
#   'attributes': 96,
#   'classes': 2,
#   'accuracy': 0.8449723869431165,
#   'kappa': 0.6617126082522584,
#   'train_time_mean': 0.3359767198562622,
#   'test_time_mean': 0.3788926601409912,
#   'total_time_mean': 0.7148693799972534,
#   'train_time': 0.6719534397125244,
#   'test_time': 0.7577853202819824,
#   'total_time': 0.7577853202819824},
#  {'dataset': 'ECG5000',
#   'classifier': 'keras_3_Dilated_Conv',
#   'instances': 5000,
#   'attributes': 140,
#   'classes': 5,
#   'accuracy': 0.9402802972249411,
#   'kappa': 0.8852282561651952,
#   'train_time_mean': 0.34341703770394794,
#   'test_time_mean': 0.0010629861292714823,
#   'total_time_mean': 0.3444800238332194,
#   'train_time': 171.36510181427002,
#   'test_time': 0.5304300785064697,
#   'total_time': 171.8955318927765},
#  {'dataset': 'ECG5000',
#   'classifier': 'keras_parallel_3_Dilated_Conv',
#   'instances': 4990,
#   'attributes': 140,
#   'classes': 5,
#   'accuracy': 0.9509294342060125,
#   'kappa': 0.9076264907265642,
#   'train_time_mean': 0.027441942142341323,
#   'test_time_mean': 0.01249459845747403,
#   'total_time_mean': 0.03993654059981536,
#   'train_time': 13.69352912902832,
#   'test_time': 6.234804630279541,
#   'total_time': 13.69352912902832},
#  {'dataset': 'ECG5000',
#   'classifier': 'keras_parallel_3_Dilated_Conv_pooling',
#   'instances': 4990,
#   'attributes': 140,
#   'classes': 5,
#   'accuracy': 0.9520557719998352,
#   'kappa': 0.9092129180367323,
#   'train_time_mean': 0.027848196889690025,
#   'test_time_mean': 0.012802885625070943,
#   'total_time_mean': 0.04065108251476097,
#   'train_time': 13.896250247955322,
#   'test_time': 6.3886399269104,
#   'total_time': 13.896250247955322},
#  {'dataset': 'ECG5000',
#   'classifier': 'keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x10',
#   'instances': 4990,
#   'attributes': 140,
#   'classes': 5,
#   'accuracy': 0.9519915193728968,
#   'kappa': 0.9091988113736292,
#   'train_time_mean': 0.019497705127050978,
#   'test_time_mean': 0.008437152854904144,
#   'total_time_mean': 0.027934857981955122,
#   'train_time': 9.729354858398438,
#   'test_time': 4.210139274597168,
#   'total_time': 9.729354858398438},
#  ...]

# %%
res = pd.DataFrame(metrics_ls[:-1], columns=['dataset','classifier','instances', 'attributes', 'classes','accuracy', 'kappa', 'train_time_mean', 'test_time_mean', 'total_time_mean', 'train_time', 'test_time', 'total_time'])
res = res.sort_values(by=['dataset', 'classifier'])
res.to_csv(_RES_FILE_PATH, index=False)

# %%
errors
# Out:
# [('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'BeetleFly',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'BeetleFly',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'BeetleFly',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BeetleFly/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40',
#   'BirdChicken',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40',
#   'BirdChicken',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40',
#   'BirdChicken',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/BirdChicken/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x40/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x120',
#   'Meat',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x120/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/Meat/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x120/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_100x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_10x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_110x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_120x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_20x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_40x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_5x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_60x60/data.csv'"),
#  ('keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x60',
#   'OliveOil',
#   "[Errno 2] File b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x60/data.csv' does not exist: b'../../DSClassificationResults/DSClassificationResults_keras/OliveOil/keras_parallel_keras_parallel_3_Dilated_Conv_pooling_80x60/data.csv'"),
#  ('MOA_KUE', 'FordA', 'No columns to parse from file'),
#  ('MOA_KUE', 'FordB', 'No columns to parse from file'),
#  ('MOA_KUE', 'Wafer', 'No columns to parse from file')]

# %%
## DEPRECATED - DO NOT USE
#_BATCH_SIZE = 10
#_NUM_BATCH_FED = 40
#
#errors = []
#metrics_ls = []
#
#for result_dir in _RESULT_DIR:
#    datasets = sorted(os.listdir(result_dir))
#    for dataset in datasets:
#        models = sorted(os.listdir(os.path.join(result_dir, dataset)))
#        for model in models:               
#            file_path = os.path.join(result_dir, dataset, model, _FILE_NAME)
#            
#            try:
#                metrics = pd.read_csv(file_path)
#            except Exception:
#                errors.append(model + " - " + dataset)
#                continue
#            
#            if metrics['total'].max() <= _BATCH_SIZE*_NUM_BATCH_FED:
#                continue
#            
#            metrics = metrics[metrics['total'] > _BATCH_SIZE*_NUM_BATCH_FED]
#            
#            if model.startswith("MOA"):
#                metrics['accuracy'] = metrics['accuracy']/100. 
#                
#            metrics_summary = {'dataset':dataset,
#                      'classifier':model,
#                      'total':metrics['total'].max(),
#                      'tp':metrics['tp'].mean() if 'tp' in metrics.columns else "",
#                      'tn':metrics['tn'].mean() if 'tn' in metrics.columns else "", 
#                      'fp':metrics['fp'].mean() if 'fp' in metrics.columns else "",
#                      'fn':metrics['fn'].mean() if 'fn' in metrics.columns else "",
#                      'precision':metrics['precision'].mean() if 'precision' in metrics.columns else "",
#                      'recall':metrics['recall'].mean() if 'recall' in metrics.columns else "",
#                      'f1':metrics['f1'].mean() if 'f1' in metrics.columns else "",
#                      'fbeta':metrics['fbeta'].mean() if 'fbeta' in metrics.columns else "",
#                      'accuracy':metrics['accuracy'].mean() if 'accuracy' in metrics.columns else "",
#                      'train_time_s':metrics['train_time'].sum() if 'train_time' in metrics.columns else "",
#                      'test_time_s':metrics['test_time'].sum() if 'test_time' in metrics.columns else ""
#                     }
#            metrics_ls.append(metrics_summary)
#
#res = pd.DataFrame(metrics_ls, columns=['dataset','classifier','total','tp','tn','fp','fn','precision','recall','f1','fbeta','accuracy','train_time_s','test_time_s'])
#res = res.sort_values(by=['dataset', 'classifier'])
#res.to_csv(_RES_FILE_PATH, index=False)
#
#if errors:
#    print("Errors: " + str(errors))
#
