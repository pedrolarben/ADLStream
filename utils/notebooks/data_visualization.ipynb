# %%
import arff
from scipy.io import arff
import pandas as pd

_RESULT_DIR = '../../datasets_arff/timeseries/'

data, meta = arff.loadarff(_RESULT_DIR +'ArrowHead.arff')
attributes = [x for x in meta]
print(attributes)
df = pd.DataFrame(data)

df.head()
# Out:
# ['att0', 'att1', 'att10', 'att100', 'att101', 'att102', 'att103', 'att104', 'att105', 'att106', 'att107', 'att108', 'att109', 'att11', 'att110', 'att111', 'att112', 'att113', 'att114', 'att115', 'att116', 'att117', 'att118', 'att119', 'att12', 'att120', 'att121', 'att122', 'att123', 'att124', 'att125', 'att126', 'att127', 'att128', 'att129', 'att13', 'att130', 'att131', 'att132', 'att133', 'att134', 'att135', 'att136', 'att137', 'att138', 'att139', 'att14', 'att140', 'att141', 'att142', 'att143', 'att144', 'att145', 'att146', 'att147', 'att148', 'att149', 'att15', 'att150', 'att151', 'att152', 'att153', 'att154', 'att155', 'att156', 'att157', 'att158', 'att159', 'att16', 'att160', 'att161', 'att162', 'att163', 'att164', 'att165', 'att166', 'att167', 'att168', 'att169', 'att17', 'att170', 'att171', 'att172', 'att173', 'att174', 'att175', 'att176', 'att177', 'att178', 'att179', 'att18', 'att180', 'att181', 'att182', 'att183', 'att184', 'att185', 'att186', 'att187', 'att188', 'att189', 'att19', 'att190', 'att191', 'att192', 'att193', 'att194', 'att195', 'att196', 'att197', 'att198', 'att199', 'att2', 'att20', 'att200', 'att201', 'att202', 'att203', 'att204', 'att205', 'att206', 'att207', 'att208', 'att209', 'att21', 'att210', 'att211', 'att212', 'att213', 'att214', 'att215', 'att216', 'att217', 'att218', 'att219', 'att22', 'att220', 'att221', 'att222', 'att223', 'att224', 'att225', 'att226', 'att227', 'att228', 'att229', 'att23', 'att230', 'att231', 'att232', 'att233', 'att234', 'att235', 'att236', 'att237', 'att238', 'att239', 'att24', 'att240', 'att241', 'att242', 'att243', 'att244', 'att245', 'att246', 'att247', 'att248', 'att249', 'att25', 'att250', 'att26', 'att27', 'att28', 'att29', 'att3', 'att30', 'att31', 'att32', 'att33', 'att34', 'att35', 'att36', 'att37', 'att38', 'att39', 'att4', 'att40', 'att41', 'att42', 'att43', 'att44', 'att45', 'att46', 'att47', 'att48', 'att49', 'att5', 'att50', 'att51', 'att52', 'att53', 'att54', 'att55', 'att56', 'att57', 'att58', 'att59', 'att6', 'att60', 'att61', 'att62', 'att63', 'att64', 'att65', 'att66', 'att67', 'att68', 'att69', 'att7', 'att70', 'att71', 'att72', 'att73', 'att74', 'att75', 'att76', 'att77', 'att78', 'att79', 'att8', 'att80', 'att81', 'att82', 'att83', 'att84', 'att85', 'att86', 'att87', 'att88', 'att89', 'att9', 'att90', 'att91', 'att92', 'att93', 'att94', 'att95', 'att96', 'att97', 'att98', 'att99', 'class']
#      att0    att1   att10   att100   att101   att102   att103   att104  \
# 0 -2.0043 -1.9856 -1.5625 -0.33682 -0.41691 -0.51629 -0.60909 -0.70067
# 1 -2.0484 -2.0432 -1.8748 -0.81404 -0.71559 -0.61995 -0.57071 -0.40781
# 2 -1.7458 -1.7574 -1.4359 -0.54407 -0.49438 -0.43919 -0.35388 -0.28434
# 3 -1.9698 -1.9818 -1.5251 -0.31372 -0.39925 -0.49718 -0.59611 -0.64577
# 4 -1.9608 -1.9304 -1.3657 -0.80312 -0.67869 -0.64304 -0.53857 -0.46032
#
#     att105   att106  ...       att91     att92     att93     att94     att95  \
# 0 -0.78999 -0.87948  ...   -0.110900 -0.092711 -0.137440 -0.162290 -0.174120
# 1 -0.39385 -0.25676  ...   -1.045000 -1.053800 -1.056400 -1.057700 -1.055500
# 2 -0.20565 -0.11971  ...   -0.479300 -0.483240 -0.490770 -0.498270 -0.528810
# 3 -0.76439 -0.86151  ...    0.047606  0.022990  0.008791 -0.036626 -0.049272
# 4 -0.34411 -0.22047  ...   -1.325700 -1.325700 -1.277100 -1.206100 -1.159900
#
#       att96     att97    att98    att99  class
# 0 -0.190560 -0.211860 -0.25425 -0.29460    0.0
# 1 -1.051600 -1.048800 -1.04470 -0.90304    1.0
# 2 -0.601640 -0.629110 -0.64854 -0.58819    0.0
# 3 -0.040425 -0.073027 -0.10762 -0.21711    0.0
# 4 -1.110900 -1.036000 -0.98095 -0.89444    1.0
#
# [5 rows x 252 columns]

# %%
df.shape
# Out:
# (211, 252)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df.iloc[1])
plt.show()
